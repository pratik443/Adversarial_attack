# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Univ of Surrey Work/sketch_adversarial-master/rap_attack-main
# Out:
# /content/drive/MyDrive/Univ of Surrey Work/sketch_adversarial-master/rap_attack-main

# %%
# !python3 rap_attack.py
# Out:
# Traceback (most recent call last):
#   File "rap_attack.py", line 269, in <module>
#     image = plt.imread("records/origin_example.jpg")[:, :, 0]
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
